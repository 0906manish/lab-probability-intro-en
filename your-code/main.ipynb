# %% [markdown]
# # Probability

# %% [markdown]
# ## Challenge 1
# There is a box with 10 white balls, 12 red balls and 8 black balls. Calculate the probability of:
# * Taking a white ball out.
# * Taking a white ball on first extraction and a black ball out on second extraction without replacing the first one.
# * Taking a white ball on first extraction and a black ball out on second extraction replacing the first one.
# * Taking 3 balls and them being all different colours.

# %%
# YOUR CODE HERE
def Probcomp0(B_w, B_r, B_b):
    T = B_w + B_r+ B_b
    return B_w/T
def Probcomp1(B_w, B_r, B_b):
    T = B_w + B_r+ B_b
    T_1 = (B_w-1)+ B_r + B_b
    return (B_w/T)*(B_b/T_1)
def Probcomp2(B_w, B_r, B_b):
    T = B_w + B_r+ B_b
    return (B_w/T)*(B_b/T)
def Probcomp3(B_w, B_r, B_b):
    T = B_w + B_r+ B_b
    T_1 = (B_w-1)+ B_r + B_b
    T_2 = (B_w-1)+ (B_r-1) + B_b
    return 6*(B_w/T * B_r/T_1 *B_b/T_2)

# %%
Probcomp1(10, 12, 8)
# Out:
# 0.09195402298850575

# %% [markdown]
# ## Challenge 2
#
# You want to go on picnic on Saturday. You hate rain, and would know to plan your weekend. To help you make a decision, you gather the following data about rainy days:
#
# * 40% of all days are cloudy.
# * About 50% of cloudy days are rainy.
# * About 20% of non-cloudy days are rainy.
#
# What is the chance of rain during next Saturday?

# %%
# YOUR CODE HERE
def probcomp2(cd: float, cdr: float, ncdr: float):
    return cd*cdr + (1 -cd)*ncdr

# %% [markdown]
# ## Challenge 3
#
# A and B are events of a probability such that $P(A) = 0.3$, $P(B) = 0.6$ and $P(A \cap B) = 0.1$
#
# Which of the following statements are true?
# **HINT: draw a big Venn Diagram by your side**
# * $P(\overline{A}) = 0.7$
# * $P(A \cup B) = 0.6$
# * $P(A \cap \overline{B}) = 0.2$
# * $P(A \cup \overline{A}) = 1$
# * $P(A \cap (B \cup \overline{B})) = 0.4$
# * $P(\overline{A} \cap \overline{B}) = 0.3$
# * $P(\overline{A \cap B}) = 0.9$

# %%
# YOUR CODE HERE
x = float(input("Please Enter the Probability of event A"))
y = float(input("Please Enter the Probability of event B"))
z = float(input("Please Enter the Probability of event A intersection B"))
def probcom(p):
    if 1- p ==1-x:
        return "complement probability is right"
def probcomuni(x, y, z):
    return x + y-z == 0.6 
def prob3(x, y):
    return x *(1-y) == 0.2
def uniprob(x):
    return x + 1-x==1
def prob5(x, y):
    return x== 0.4
def prob6(x, y):
    return (1-x)*(1-y)==0.3
def prob7(x, y):
    return (1-x)+(1-y)== 0.9

# %% [markdown]
# ## Challenge 4
#
#  * If someone flies to China, the probability of getting Covid is 1%
#  * If someone flies to Italy, the probability of getting Covid is 20%
#
# I roll 1 dice with numbers 1, 2, 3, 4, 5, 6:
#  * If 1: I fly to Italy
#  * If not 1: I fly to China
#
# During my trip, I got Covid. What is the probability that I flew to China?

# %%
# YOUR CODE HERE
#cc= 1/100
#ic = 20/100
#P_i = 1/6
#P_c = 5/6
def prob_going_china_get_covid(cc, ic, P_c, P_i):
    return (cc*P_c)/(P_c * cc + P_i * ic)

# %%
prob_going_china_get_covid(1/100, 20/100, 5/6, 1/6)
# Out:
# 0.2

# %% [markdown]
# ## BONUS
#
# You roll 2 dice. What is the probability that the sum of the numbers is 7? And 8? And 9? Then simulate 10000 times and draw a countplot.

# %% [markdown]
# your explanation here

# %%
# YOUR CODE HERE
E_7 = ["3&4", "5&2", "6&1"]
E_8 = ["4&4", "5&3", "6&2"]
E_9 = ["6&3", "5&4"]
def probsum7():
    return (2*len(E_7))/ 36
def probsum8():
    return (2*len(E_8))/ 36
def probsum9():
    return (2*len(E_9))/ 36

# %%
import random
import pandas as pd
import matplotlib.pyplot as pyplot
import seaborn as sns
x = []
a = []
b = []
c = []
for i in range(100000):
    y = random.randint(1,6)
    z = random.randint(1,6)
    x.append(y + z)
for item in x:
    if item ==7:
        a.append(item)
    if item == 8:
        b.append(item)
    if item == 9:
        c.append(item)
len(a), len(b), len(c)     
dicta = {"7": len(a), "8": len(b), "9": len(c)} 
df = pd.DataFrame(x)
#sns.countplot(x)
df1= df.value_counts(normalize = True)
df1.plot(kind = 'bar', legend = True)
# Out:
# <Axes: xlabel='0'>
